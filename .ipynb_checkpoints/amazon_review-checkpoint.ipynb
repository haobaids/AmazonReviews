# %%
import pandas as pd
import gzip
import simplejson as json
import seaborn as sns
import re

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df_review = getDF('resources/AMAZON_FASHION.json.gz')

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 883636 entries, 0 to 883635
# Data columns (total 12 columns):
# overall           883636 non-null float64
# verified          883636 non-null bool
# reviewTime        883636 non-null object
# reviewerID        883636 non-null object
# asin              883636 non-null object
# reviewerName      883544 non-null object
# reviewText        882403 non-null object
# summary           883103 non-null object
# unixReviewTime    883636 non-null int64
# vote              79900 non-null object
# style             304569 non-null object
# image             28807 non-null object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 81.7+ MB

# %%
df_review.describe()
# Out:
#             overall  unixReviewTime
# count  883636.00000    8.836360e+05
# mean        3.90694    1.456751e+09
# std         1.41828    4.430691e+07
# min         1.00000    1.036973e+09
# 25%         3.00000    1.434240e+09
# 50%         5.00000    1.462234e+09
# 75%         5.00000    1.484266e+09
# max         5.00000    1.538352e+09

# %%
df_review.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  reviewerName  \
# 0      5.0      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521         Tracy
# 1      2.0      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521     Sonja Lau
# 2      4.0     False  08 25, 2014  A2MWC41EW7XL15  7106116521      Kathleen
# 3      2.0      True  08 24, 2014  A2UH2QQ275NV45  7106116521   Jodi Stoner
# 4      3.0     False  07 27, 2014   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                           reviewText  \
# 0                             Exactly what I needed.
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 4                                               Okay
#
#                                              summary  unixReviewTime vote  \
# 0                             perfect replacements!!      1413763200  NaN
# ...

# %%
df_meta = getDF('resources/meta_AMAZON_FASHION.json.gz')

# %%
df_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186637 entries, 0 to 186636
# Data columns (total 15 columns):
# title           186632 non-null object
# image           132017 non-null object
# brand           139957 non-null object
# feature         123875 non-null object
# rank            180222 non-null object
# date            185001 non-null object
# asin            186637 non-null object
# description     15869 non-null object
# price           17799 non-null object
# also_view       11595 non-null object
# also_buy        21642 non-null object
# fit             4831 non-null object
# details         885 non-null object
# similar_item    317 non-null object
# tech1           97 non-null object
# dtypes: object(15)
# memory usage: 22.8+ MB

# %%
df_meta.tail()
# Out:
#                                                     title  \
# 186632  JT Women's Elegant Off Shoulder Chiffon Maxi L...
# 186633  Microcosm Retro Vintage Black Crochet Lace One...
# 186634  Lookatool Classic Plain Vintage Army Military ...
# 186635  Edith Windsor Women's Deep V-neck Beaded Sequi...
# 186636  Aeropostale Women's Sun & Waves Crop Cami L Gr...
#
#                                                     image          brand  \
# 186632  [https://images-na.ssl-images-amazon.com/image...             JT
# 186633  [https://images-na.ssl-images-amazon.com/image...      Microcosm
# 186634  [https://images-na.ssl-images-amazon.com/image...      Lookatool
# 186635  [https://images-na.ssl-images-amazon.com/image...  Edith Windsor
# 186636  [https://images-na.ssl-images-amazon.com/image...            NaN
#
#                                                   feature  \
# 186632                                                NaN
# ...

# %%
# subset data of interest
df_review = df_review[['asin', 'overall']]
df_meta = df_meta[['asin','brand','rank','price']]

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 883636 entries, 0 to 883635
# Data columns (total 2 columns):
# asin       883636 non-null object
# overall    883636 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 20.2+ MB

# %%
df_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186637 entries, 0 to 186636
# Data columns (total 4 columns):
# asin     186637 non-null object
# brand    139957 non-null object
# rank     180222 non-null object
# price    17799 non-null object
# dtypes: object(4)
# memory usage: 7.1+ MB

# %% [markdown]
# ### Clean-up Data and Feature Engineering

# %%
df_review.overall.unique()
# Out:
# array([5., 2., 4., 3., 1.])

# %%
# sns.distplot(df_review['overall'], kde=False)
sns.countplot(df_review['overall'])

# %%
df_meta.brand.unique()
# Out:
# array(['Group Publishing (CO)', nan, 'Christopher Manos', ..., 'Hosaire',
#        'Ginee18', 'Vincico'], dtype=object)

# %%
# sns.countplot(df_meta['brand'])

# %%
df_meta['rank'].head()
# Out:
# 0    13,052,976inClothing,Shoesamp;Jewelry(
# 1    11,654,581inClothing,Shoesamp;Jewelry(
# 2        19,308,073inClothing,ShoesJewelry(
# 3        19,734,184inClothing,ShoesJewelry(
# 4    10,558,646inClothing,Shoesamp;Jewelry(
# Name: rank, dtype: object

# %%
df_meta['rank']
# Out:
# 0         13,052,976inClothing,Shoesamp;Jewelry(
# 1         11,654,581inClothing,Shoesamp;Jewelry(
# 2             19,308,073inClothing,ShoesJewelry(
# 3             19,734,184inClothing,ShoesJewelry(
# 4         10,558,646inClothing,Shoesamp;Jewelry(
# 5         16,179,013inClothing,Shoesamp;Jewelry(
# 6              7,787,039inClothing,ShoesJewelry(
# 7              9,854,284inClothing,ShoesJewelry(
# 8         16,147,550inClothing,Shoesamp;Jewelry(
# 9             16,714,561inClothing,ShoesJewelry(
# 10             2,081,098inClothing,ShoesJewelry(
# 11            25,698,912inClothing,ShoesJewelry(
# 12            25,850,143inClothing,ShoesJewelry(
# 13            19,411,377inClothing,ShoesJewelry(
# 14        21,572,343inClothing,Shoesamp;Jewelry(
# 15        22,202,218inClothing,Shoesamp;Jewelry(
# 16         9,900,066inClothing,Shoesamp;Jewelry(
# 17         3,725,957inClothing,Shoesamp;Jewelry(
# 18               468,314inClothing,ShoesJewelry(
# ...

# %%
df_meta_new = df_meta[df_meta['rank'].notnull()]
# df_meta_new['rankstring'] = df_meta_new['rank'].str.replace(r'[a-zA-Z,;()<>#]+','').apply(lambda x: float(x))

df_meta_new['rankstring'] = df_meta_new['rank'].str.replace(r'[a-zA-Z,;()<>#]+','')
df_meta_new['rankstring']
# df_meta_new['rankstring'] = df_meta_new['rank'].str.replace(r'[a-zA-Z,;()<>#]+ ','').apply(lambda x:x.split('&')[0]).apply(lambda x: float(x))


# df_meta_new['rankstring'] = df_meta_new['rank'].str.replace(r'[a-zA-Z,;()<>#]+ ','').apply(lambda x:x.split('&')[0]).apply(lambda x: float(x))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 0         13052976
# 1         11654581
# 2         19308073
# 3         19734184
# 4         10558646
# 5         16179013
# 6          7787039
# 7          9854284
# 8         16147550
# 9         16714561
# 10         2081098
# 11        25698912
# 12        25850143
# 13        19411377
# 14        21572343
# 15        22202218
# 16         9900066
# 17         3725957
# 18          468314
# 19        23888557
# 20        20806337
# 21        26245347
# 26        24869172
# 27        26241540
# 32        26375869
# 38        26228199
# 42        23461935
# 45        23853677
# 48        26173835
# ...

# %%
df_meta_new.iloc[2311]
# Out:
# asin                                  B000J5XE9K
# brand                                        NaN
# rank          24,646,033inClothing,ShoesJewelry(
# price                                        NaN
# rankstring                              24646033
# Name: 2679, dtype: object

# %%
print(len(df_meta_new))
print(len(df_meta_new.loc[df_meta_new['rankstring'].str.find('&')!=-1,:]))
# Out:
# 180222
# 514

# %%
df_meta_new['rankarray']=df_meta_new['rankstring'].str.split('>#')
df_meta_new.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          asin                   brand                                    rank  \
# 0  0764443682   Group Publishing (CO)  13,052,976inClothing,Shoesamp;Jewelry(
# 1  1291691480                     NaN  11,654,581inClothing,Shoesamp;Jewelry(
# 2  1940280001       Christopher Manos      19,308,073inClothing,ShoesJewelry(
# 3  1940735033  Flickerlamp Publishing      19,734,184inClothing,ShoesJewelry(
# 4  1940967805                     NaN  10,558,646inClothing,Shoesamp;Jewelry(
#
#    price rankstring   rankarray
# 0    NaN   13052976  [13052976]
# 1    NaN   11654581  [11654581]
# ...

# %%
df_meta_new_onerank = df_meta_new.loc[df_meta_new['rankstring'].str.find('&')==-1,:]
df_meta_new_onerank.head()
# Out:
#          asin                   brand                                    rank  \
# 0  0764443682   Group Publishing (CO)  13,052,976inClothing,Shoesamp;Jewelry(
# 1  1291691480                     NaN  11,654,581inClothing,Shoesamp;Jewelry(
# 2  1940280001       Christopher Manos      19,308,073inClothing,ShoesJewelry(
# 3  1940735033  Flickerlamp Publishing      19,734,184inClothing,ShoesJewelry(
# 4  1940967805                     NaN  10,558,646inClothing,Shoesamp;Jewelry(
#
#    price rankstring   rankarray
# 0    NaN   13052976  [13052976]
# 1    NaN   11654581  [11654581]
# 2    NaN   19308073  [19308073]
# 3    NaN   19734184  [19734184]
# 4  $4.50   10558646  [10558646]

# %%
df_meta_new_onerank['rank1category']=df_meta_new_onerank['rank'].str.split('in',1).apply(lambda x:x[1])
df_meta_new_onerank['rank1']=df_meta_new_onerank['rankstring'].apply(lambda x: float(x))
df_meta_new_onerank.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          asin                   brand                                    rank  \
# 0  0764443682   Group Publishing (CO)  13,052,976inClothing,Shoesamp;Jewelry(
# 1  1291691480                     NaN  11,654,581inClothing,Shoesamp;Jewelry(
# ...

# %%
df_meta_new_onerank = df_meta_new_onerank.drop(['rankstring', 'rankarray'], axis=1)
df_meta_new_onerank.head()
# Out:
#          asin                   brand                                    rank  \
# 0  0764443682   Group Publishing (CO)  13,052,976inClothing,Shoesamp;Jewelry(
# 1  1291691480                     NaN  11,654,581inClothing,Shoesamp;Jewelry(
# 2  1940280001       Christopher Manos      19,308,073inClothing,ShoesJewelry(
# 3  1940735033  Flickerlamp Publishing      19,734,184inClothing,ShoesJewelry(
# 4  1940967805                     NaN  10,558,646inClothing,Shoesamp;Jewelry(
#
#    price               rank1category       rank1
# 0    NaN  Clothing,Shoesamp;Jewelry(  13052976.0
# 1    NaN  Clothing,Shoesamp;Jewelry(  11654581.0
# 2    NaN      Clothing,ShoesJewelry(  19308073.0
# 3    NaN      Clothing,ShoesJewelry(  19734184.0
# 4  $4.50  Clothing,Shoesamp;Jewelry(  10558646.0

# %%
df_meta_new_onerank.columns
# Out:
# Index(['asin', 'brand', 'rank', 'price', 'rank1category', 'rank1'], dtype='object')

# %%
df_meta_new_morerank = df_meta_new.loc[df_meta_new['rankstring'].str.find('&')!=-1,:].reset_index()
df_meta_new_morerank.head()
# Out:
#    index        asin            brand  \
# 0   1162  B0007YT1DQ           Coshom
# 1   1184  B0008F6WMM          Aeromax
# 2   2129  B000HCX6PC            Mundi
# 3   2311  B000I5OFEY  Nick &amp; Nora
# 4   3020  B000M129CO     LEISURE ARTS
#
#                                                 rank   price  \
# 0  [>#250,901 in Electronics (See Top 100 in Elec...   $8.99
# 1  [>#16,931 in Toys & Games (See Top 100 in Toys...  $41.63
# 2  [>#25,901,372 in Clothing, Shoes & Jewelry (Se...     NaN
# 3  >#24,963,613 in Clothing, Shoes & Jewelry (See...     NaN
# 4  >#2,424,303 in Arts, Crafts & Sewing (See Top ...     NaN
#
#                                           rankstring  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  24963613    &    100    & 53307    &    &
# 4            2424303    &    100    & 414391    &
#
# ...

# %%
df_meta_new_morerank['newrank']=df_meta_new_morerank['rank'].apply(lambda x: x[0] if isinstance(x, list) else x)
df_meta_new_morerank.head()
# Out:
#    index        asin            brand  \
# 0   1162  B0007YT1DQ           Coshom
# 1   1184  B0008F6WMM          Aeromax
# 2   2129  B000HCX6PC            Mundi
# 3   2311  B000I5OFEY  Nick &amp; Nora
# 4   3020  B000M129CO     LEISURE ARTS
#
#                                                 rank   price  \
# 0  [>#250,901 in Electronics (See Top 100 in Elec...   $8.99
# 1  [>#16,931 in Toys & Games (See Top 100 in Toys...  $41.63
# 2  [>#25,901,372 in Clothing, Shoes & Jewelry (Se...     NaN
# 3  >#24,963,613 in Clothing, Shoes & Jewelry (See...     NaN
# 4  >#2,424,303 in Arts, Crafts & Sewing (See Top ...     NaN
#
#                                           rankstring  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  24963613    &    100    & 53307    &    &
# 4            2424303    &    100    & 414391    &
#
# ...

# %%
df_meta_new_morerank['rankarray1']=df_meta_new_morerank['newrank'].str.split('>#').apply(lambda x:x[1])
df_meta_new_morerank.head()
# Out:
#    index        asin            brand  \
# 0   1162  B0007YT1DQ           Coshom
# 1   1184  B0008F6WMM          Aeromax
# 2   2129  B000HCX6PC            Mundi
# 3   2311  B000I5OFEY  Nick &amp; Nora
# 4   3020  B000M129CO     LEISURE ARTS
#
#                                                 rank   price  \
# 0  [>#250,901 in Electronics (See Top 100 in Elec...   $8.99
# 1  [>#16,931 in Toys & Games (See Top 100 in Toys...  $41.63
# 2  [>#25,901,372 in Clothing, Shoes & Jewelry (Se...     NaN
# 3  >#24,963,613 in Clothing, Shoes & Jewelry (See...     NaN
# 4  >#2,424,303 in Arts, Crafts & Sewing (See Top ...     NaN
#
#                                           rankstring  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  24963613    &    100    & 53307    &    &
# 4            2424303    &    100    & 414391    &
#
# ...

# %%
df_meta_new_morerank['rank1']=df_meta_new_morerank['rankarray1'].str.split(' ').apply(lambda x:x[0]).str.replace(',','').apply(lambda x: float(x))
df_meta_new_morerank['rank1category']=df_meta_new_morerank['rankarray1'].str.split('in',1).apply(lambda x:x[1])
df_meta_new_morerank.head(20)
# Out:
#     index        asin                brand  \
# 0    1162  B0007YT1DQ               Coshom
# 1    1184  B0008F6WMM              Aeromax
# 2    2129  B000HCX6PC                Mundi
# 3    2311  B000I5OFEY      Nick &amp; Nora
# 4    3020  B000M129CO         LEISURE ARTS
# 5    3707  B000UJQB1S                Bosca
# 6    3716  B000UODH2Y              Rubie's
# 7    3980  B000Y50DIA             JanSport
# 8    4380  B00162YWGE               Zucker
# 9    4530  B0017CYBR8         Design House
# 10   4768  B001B3FY42        Ring Snuggies
# 11   4864  B001CK1TOI           Leg Avenue
# 12   4988  B001EIPBIS  California Costumes
# 13   5164  B001HKAM82        Royce Leather
# 14   5962  B0025VYH8I          Vine Branch
# 15   6055  B0027VT646            Fun World
# 16   6168  B002BBE0AC     Small World Toys
# 17   6425  B002KX0RVM      Bristol Novelty
# 18   6489  B002NGL9FE  California Costumes
# 19   7270  B003ELOPYY       Stephen Joseph
#
# ...

# %%
df_meta_new_morerank=df_meta_new_morerank[['asin', 'brand', 'rank', 'price', 'rank1category', 'rank1']]
df_meta_new_morerank.head()
# Out:
#          asin            brand  \
# 0  B0007YT1DQ           Coshom
# 1  B0008F6WMM          Aeromax
# 2  B000HCX6PC            Mundi
# 3  B000I5OFEY  Nick &amp; Nora
# 4  B000M129CO     LEISURE ARTS
#
#                                                 rank   price  \
# 0  [>#250,901 in Electronics (See Top 100 in Elec...   $8.99
# 1  [>#16,931 in Toys & Games (See Top 100 in Toys...  $41.63
# 2  [>#25,901,372 in Clothing, Shoes & Jewelry (Se...     NaN
# 3  >#24,963,613 in Clothing, Shoes & Jewelry (See...     NaN
# 4  >#2,424,303 in Arts, Crafts & Sewing (See Top ...     NaN
#
#                                        rank1category       rank1
# 0           Electronics (See Top 100 in Electronics)    250901.0
# 1         Toys & Games (See Top 100 in Toys & Games)     16931.0
# 2   Clothing, Shoes & Jewelry (See Top 100 in Clo...  25901372.0
# 3   Clothing, Shoes & Jewelry (See Top 100 in Clo...  24963613.0
# 4   Arts, Crafts & Sewing (See Top 100 in Arts, C...   2424303.0

# %%
df_meta_rank_use=pd.concat([df_meta_new_onerank, df_meta_new_morerank], ignore_index=True)
df_meta_rank_use.head()
# Out:
#          asin                   brand                                    rank  \
# 0  0764443682   Group Publishing (CO)  13,052,976inClothing,Shoesamp;Jewelry(
# 1  1291691480                     NaN  11,654,581inClothing,Shoesamp;Jewelry(
# 2  1940280001       Christopher Manos      19,308,073inClothing,ShoesJewelry(
# 3  1940735033  Flickerlamp Publishing      19,734,184inClothing,ShoesJewelry(
# 4  1940967805                     NaN  10,558,646inClothing,Shoesamp;Jewelry(
#
#    price               rank1category       rank1
# 0    NaN  Clothing,Shoesamp;Jewelry(  13052976.0
# 1    NaN  Clothing,Shoesamp;Jewelry(  11654581.0
# 2    NaN      Clothing,ShoesJewelry(  19308073.0
# 3    NaN      Clothing,ShoesJewelry(  19734184.0
# 4  $4.50  Clothing,Shoesamp;Jewelry(  10558646.0

# %%
df_meta_rank_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180222 entries, 0 to 180221
# Data columns (total 7 columns):
# asin             180222 non-null object
# brand            134912 non-null object
# rank             180222 non-null object
# price            17376 non-null object
# rank1category    180222 non-null object
# rank1            180222 non-null float64
# pricestring      17376 non-null object
# dtypes: float64(1), object(6)
# memory usage: 9.6+ MB

# %%
df_meta_rank_use.columns
# Out:
# Index(['asin', 'brand', 'rank', 'price', 'rank1category', 'rank1',
#        'pricestring', 'is_duplicate'],
#       dtype='object')

# %%
df_meta_noduplicate = df_meta_rank_use[~df_meta_rank_use.duplicated(['asin', 'brand', 'price', 'rank1category','rank1','pricestring'],keep='first')]
df_meta_noduplicate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179855 entries, 0 to 180221
# Data columns (total 8 columns):
# asin             179855 non-null object
# brand            134681 non-null object
# rank             179855 non-null object
# price            17365 non-null object
# rank1category    179855 non-null object
# rank1            179855 non-null float64
# pricestring      17365 non-null object
# is_duplicate     179855 non-null bool
# dtypes: bool(1), float64(1), object(6)
# memory usage: 11.1+ MB

# %%
df_meta_noduplicate['pricestring'] = df_meta_noduplicate['price'].str.replace(r'[a-zA-Z,;()<>#$]+','')
df_meta_pricetemp = df_meta_noduplicate.loc[df_meta_noduplicate['pricestring'].notnull(),:]
df_meta_pricerange = df_meta_pricetemp.loc[df_meta_pricetemp['price'].str.find('-')!=-1,:]
df_meta_pricerange[['Pricemin','Pricemax']] = df_meta_pricerange['pricestring'].str.split('-',expand=True)

df_meta_pricerange['newprice']= (df_meta_pricerange['Pricemin'].apply(lambda x: float(x))+df_meta_pricerange['Pricemax'].apply(lambda x: float(x)))/2
df_meta_pricerange.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            asin                brand                                    rank  \
# 371  B0002Z1JNK              Pleaser     261,979inClothing,Shoesamp;Jewelry(
# 756  B00062NHH0                  NaN      55,254inClothing,Shoesamp;Jewelry(
# ...

# %%
df_meta_pricetemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17365 entries, 4 to 180221
# Data columns (total 8 columns):
# asin             17365 non-null object
# brand            13839 non-null object
# rank             17365 non-null object
# price            17365 non-null object
# rank1category    17365 non-null object
# rank1            17365 non-null float64
# pricestring      17365 non-null object
# is_duplicate     17365 non-null bool
# dtypes: bool(1), float64(1), object(6)
# memory usage: 1.1+ MB

# %%
del df_meta_pricerange['Pricemin'], df_meta_pricerange['Pricemax']
df_meta_pricerange.head()
# Out:
#            asin                brand                                    rank  \
# 371  B0002Z1JNK              Pleaser     261,979inClothing,Shoesamp;Jewelry(
# 756  B00062NHH0                  NaN      55,254inClothing,Shoesamp;Jewelry(
# 803  B0006B5C0G  Schaefer Outfitters  10,565,017inClothing,Shoesamp;Jewelry(
# 805  B0006BHRZ4  Schaefer Outfitters  10,631,142inClothing,Shoesamp;Jewelry(
# 806  B0006BHTG6  Schaefer Outfitters   6,948,052inClothing,Shoesamp;Jewelry(
#
#                  price               rank1category       rank1  \
# 371    $52.95 - $75.00  Clothing,Shoesamp;Jewelry(    261979.0
# 756    $23.97 - $39.95  Clothing,Shoesamp;Jewelry(     55254.0
# 803  $180.00 - $205.00  Clothing,Shoesamp;Jewelry(  10565017.0
# 805  $115.00 - $125.00  Clothing,Shoesamp;Jewelry(  10631142.0
# 806  $140.00 - $150.00  Clothing,Shoesamp;Jewelry(   6948052.0
#
#          pricestring  is_duplicate  newprice
# 371    52.95 - 75.00         False    63.975
# ...

# %%
df_meta_pricerange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2704 entries, 371 to 179630
# Data columns (total 9 columns):
# asin             2704 non-null object
# brand            1955 non-null object
# rank             2704 non-null object
# price            2704 non-null object
# rank1category    2704 non-null object
# rank1            2704 non-null float64
# pricestring      2704 non-null object
# is_duplicate     2704 non-null bool
# newprice         2704 non-null float64
# dtypes: bool(1), float64(2), object(6)
# memory usage: 192.8+ KB

# %%
df_meta_pricesingle = df_meta_pricetemp.loc[df_meta_pricetemp['price'].str.find('-')==-1,:]
df_meta_pricesingle['newprice']=df_meta_pricesingle['pricestring'].apply(lambda x: float(x))
df_meta_pricesingle.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           asin               brand                                    rank  \
# 4   1940967805                 NaN  10,558,646inClothing,Shoesamp;Jewelry(
# 17  9654263246         Roar Carbon   3,725,957inClothing,Shoesamp;Jewelry(
# 18  B00004T3SN  Shimmer Anne Shine         468,314inClothing,ShoesJewelry(
# 48  B00007GDFV              Buxton      43,930inClothing,Shoesamp;Jewelry(
# 81  B0000A9Y61                 NaN       4,979,477inClothing,ShoesJewelry(
#
#      price               rank1category       rank1 pricestring  is_duplicate  \
# 4    $4.50  Clothing,Shoesamp;Jewelry(  10558646.0        4.50         False
# ...

# %%
df_meta_pricesingle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14661 entries, 4 to 180221
# Data columns (total 9 columns):
# asin             14661 non-null object
# brand            11884 non-null object
# rank             14661 non-null object
# price            14661 non-null object
# rank1category    14661 non-null object
# rank1            14661 non-null float64
# pricestring      14661 non-null object
# is_duplicate     14661 non-null bool
# newprice         14661 non-null float64
# dtypes: bool(1), float64(2), object(6)
# memory usage: 1.0+ MB

# %%
df_meta_pricerange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2704 entries, 371 to 179630
# Data columns (total 9 columns):
# asin             2704 non-null object
# brand            1955 non-null object
# rank             2704 non-null object
# price            2704 non-null object
# rank1category    2704 non-null object
# rank1            2704 non-null float64
# pricestring      2704 non-null object
# is_duplicate     2704 non-null bool
# newprice         2704 non-null float64
# dtypes: bool(1), float64(2), object(6)
# memory usage: 192.8+ KB

# %%
df_meta_price_use = pd.concat([df_meta_pricesingle, df_meta_pricerange], ignore_index=True)
df_meta_price_use = df_meta_price_use[['asin','newprice']]
df_meta_price_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17365 entries, 0 to 17364
# Data columns (total 2 columns):
# asin        17365 non-null object
# newprice    17365 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 271.4+ KB

# %%
df_meta_new_use=df_meta_noduplicate.merge(df_meta_price_use, left_on='asin', right_on='asin')
df_meta_new_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17365 entries, 0 to 17364
# Data columns (total 9 columns):
# asin             17365 non-null object
# brand            13839 non-null object
# rank             17365 non-null object
# price            17365 non-null object
# rank1category    17365 non-null object
# rank1            17365 non-null float64
# pricestring      17365 non-null object
# is_duplicate     17365 non-null bool
# newprice         17365 non-null float64
# dtypes: bool(1), float64(2), object(6)
# memory usage: 1.2+ MB

# %%
df_meta_new_use.describe()
# Out:
#               rank1      newprice
# count  1.736500e+04  17365.000000
# mean   4.658865e+06     38.325984
# std    5.059808e+06    538.936223
# min    1.540000e+02      0.010000
# 25%    1.004254e+06     10.000000
# 50%    2.997117e+06     17.590000
# 75%    6.467544e+06     32.015000
# max    2.711433e+07  69995.000000

# %%
df_review_summary = df_review.groupby('asin')['asin','overall'].median().reset_index()
df_review_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186189 entries, 0 to 186188
# Data columns (total 2 columns):
# asin       186189 non-null object
# overall    186189 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 2.8+ MB

# %%
df_use=df_meta_new_use.merge(df_review_summary, how='outer', left_on='asin', right_on='asin')
df_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186190 entries, 0 to 186189
# Data columns (total 10 columns):
# asin             186190 non-null object
# brand            13839 non-null object
# rank             17365 non-null object
# price            17365 non-null object
# rank1category    17365 non-null object
# rank1            17365 non-null float64
# pricestring      17365 non-null object
# is_duplicate     17365 non-null object
# newprice         17365 non-null float64
# overall          186189 non-null float64
# dtypes: float64(3), object(7)
# memory usage: 15.6+ MB

# %%
df_use=df_use[['asin','brand','rank1','rank1category','newprice','overall']]
df_use.head()
# Out:
#          asin               brand       rank1               rank1category  \
# 0  1940967805                 NaN  10558646.0  Clothing,Shoesamp;Jewelry(
# 1  9654263246         Roar Carbon   3725957.0  Clothing,Shoesamp;Jewelry(
# 2  B00004T3SN  Shimmer Anne Shine    468314.0      Clothing,ShoesJewelry(
# 3  B00007GDFV              Buxton     43930.0  Clothing,Shoesamp;Jewelry(
# 4  B0000A9Y61                 NaN   4979477.0      Clothing,ShoesJewelry(
#
#    newprice  overall
# 0      4.50      5.0
# 1     14.99      5.0
# 2      6.99      5.0
# 3     16.95      4.0
# 4      9.02      2.0

# %%
df_use['rank1category'].unique()
# Out:
# array(['Clothing,Shoesamp;Jewelry(', 'Clothing,ShoesJewelry(',
#        'Sportsamp;Outdoors(', 'SportsOutdoors(', 'HealthHousehold(',
#        'ToolsHomeImprovement(', 'IndustrialScientific(', 'PetSupplies(',
#        'BeautyPersonalCare(', 'AmazonLaunchpad(',
#        'CellPhonesAccessories(', 'OfficeProducts(', 'Arts,CraftsSewing(',
#        'HomeKitchen(', ' Electronics (See Top 100 in Electronics)',
#        ' Toys & Games (See Top 100 in Toys & Games)',
#        ' Office Products (See top 100)', ' Home & Kitchen (See top 100)',
#        ' Arts, Crafts & Sewing (See Top 100 in Arts, Crafts & Sewing)',
#        ' Clothing, Shoes & Jewelry (See Top 100 in Clothing, Shoes & Jewelry)',
#        ' Kitchen & Dining (See Top 100 in Kitchen & Dining)',
#        ' Home & Kitchen (See Top 100 in Home & Kitchen)',
#        ' Patio, Lawn & Garden (See Top 100 in Patio, Lawn & Garden)',
#        ' Automotive (See top 100)',
#        ' Tools & Home Improvement (See top 100)',
# ...

# %% [markdown]
# #### Missing Data

# %%
#Summarizing total Missing Values in each feature
df_meta.isnull().sum()
# Out:
# asin          0
# brand     46680
# rank       6415
# price    168838
# dtype: int64

# %%
#do we need to get rid of some missing line to go if they are missing every line except for asin and maybe no comments as well...
# replace the value with others(a lot of things is not possible to predict)..drop all missing lines and drop lines with mutiple missing features
df_meta_d = df_meta.dropna(axis = 0, how ='any') 
df_meta_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 15 columns):
# title           0 non-null object
# image           0 non-null object
# brand           0 non-null object
# feature         0 non-null object
# rank            0 non-null object
# date            0 non-null object
# asin            0 non-null object
# description     0 non-null object
# price           0 non-null object
# also_view       0 non-null object
# also_buy        0 non-null object
# fit             0 non-null object
# details         0 non-null object
# similar_item    0 non-null object
# tech1           0 non-null object
# dtypes: object(15)
# memory usage: 0.0+ bytes

# %%
df_review.isnull().sum()
# Out:
# overall                0
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# reviewerName          92
# reviewText          1233
# summary              533
# unixReviewTime         0
# vote              803736
# style             579067
# image             854829
# dtype: int64

# %%
#confirm the missing values and not missing values are correct recognized
df_meta['price'].isnull().head()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: price, dtype: bool

# %% [markdown]
# ### Decision Tree Model

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# ### Logistic Regression Model

# %% [markdown]
# ### Model Selection

# %% [markdown]
# ### Conclusion
